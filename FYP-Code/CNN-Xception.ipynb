# %%
import cv2
import os
import shutil
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense,Dropout,Flatten,BatchNormalization,MaxPooling2D,Conv2D,Input, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping,ModelCheckpoint
import keras_tuner as kt
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)

# %% [markdown]
# **Dataset Acknowledgment**:
# The dataset is the publicly available traffic congestion dataset from Kaggle.

# %%
def extract_frames(video_path, output_folder):

    cap = cv2.VideoCapture(video_path)
    image_index = 0

    while True:
        ret, frame = cap.read()

        if not ret:
            break

        frame_filename = os.path.join(output_folder, f"frame_{image_index:04d}.jpg")
        cv2.imwrite(frame_filename, frame)
        image_index += 1

    cap.release()

# %%
dataset_path = '/content/drive/My Drive/ML PERSONAL/dataset/'

# %%
non_traffic = f'{dataset_path}/non_traffic'
light_traffic = f'{dataset_path}/light_traffic'
moderate_traffic = f'{dataset_path}/moderate_traffic'
heavy_traffic = f'{dataset_path}/heavy_traffic'
congested_traffic = f'{dataset_path}/congested_traffic'

# %%
extract_frames(
    video_path = "/content/drive/My Drive/ML PERSONAL/dataset/Non-traffic related.mp4",
    output_folder = non_traffic
)

# %%
extract_frames(
    video_path = "/content/drive/My Drive/ML PERSONAL/dataset/Light Traffic.mp4",
    output_folder = light_traffic
)

# %%
extract_frames(
    video_path = "/content/drive/My Drive/ML PERSONAL/dataset/Moderate Traffic.mp4",
    output_folder = moderate_traffic
)

# %%
extract_frames(
    video_path = "/content/drive/My Drive/ML PERSONAL/dataset/Heavy Traffic.mp4",
    output_folder = heavy_traffic
)

# %%
extract_frames(
    video_path ="/content/drive/My Drive/ML PERSONAL/dataset/Congested Traffic.mp4",
    output_folder = congested_traffic
)

# %%
train_dir = f'{dataset_path}/train_dir'
valid_dir = f'{dataset_path}/valid_dir'

# %%
class1 = 'non_traffic'
class2 = 'light_traffic'
class3 = 'moderate_traffic'
class4 = 'heavy_traffic'
class5 = 'congested_traffic'

classes = [class1, class2, class3, class4, class5]

for each in classes:
    os.makedirs(os.path.join(train_dir, each), exist_ok=True)
    os.makedirs(os.path.join(valid_dir, each), exist_ok=True)

# %%
def split_data(class_dir, train_ratio, valid_ratio):
    files = os.listdir(class_dir)
    random.shuffle(files)

    num_files = len(files)
    train_split = int(train_ratio * num_files)

    train_files = files[:train_split]
    valid_files = files[train_split:]

    random.shuffle(train_files)
    random.shuffle(valid_files)

    return train_files, valid_files

# %%
train_ratio = 0.85
valid_ratio = 0.15

split_info = {}

for each in classes:

    class_dir = os.path.join(dataset_path, each)
    train, validation = split_data(class_dir, train_ratio, valid_ratio)

    train_size, validation_size = len(train), len(validation)
    split_info[each] = [train_size, validation_size]


    for file in train:
        source_path = os.path.join(class_dir, file)
        destination_path = os.path.join(train_dir, each, file)
        shutil.copy(source_path, destination_path)

    for file in validation:
        source_path = os.path.join(class_dir, file)
        destination_path = os.path.join(valid_dir, each, file)
        shutil.copy(source_path, destination_path)

# %%
img_width, img_height = 300, 300
batch_size = 256

# %%
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    brightness_range=[0.5, 1.25],
    horizontal_flip=True,
    vertical_flip=True
)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    seed=55
)
# Out:
# Found 10755 images belonging to 5 classes.

# %%
validation_datagen = ImageDataGenerator()
validation_generator = validation_datagen.flow_from_directory(
    valid_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    seed=44
)
# Out:
# Found 1900 images belonging to 5 classes.

# %%
def create_traffic_model(hp):
    base_model = Xception(
        input_shape=(img_width, img_height, 3),
        weights='imagenet',
        include_top=False,
        pooling=hp.Choice('base_model_pooling', values=['avg', 'max'])
    )
    base_model.trainable = False

    i = Input([img_width, img_height, 3])
    x = tf.keras.applications.xception.preprocess_input(i)
    x = base_model(x, training=False)
    x = BatchNormalization()(x)
    x = Dense(
        hp.Int('units_1', min_value=16, max_value=512, step=16),
        activation='relu'
    )(x)
    x = BatchNormalization()(x)
    x = Dense(
        hp.Int('units_2', min_value=16, max_value=512, step=16),
        activation='relu'
    )(x)
    x = Dropout(
        hp.Float('dropout_rate_1', min_value=0.1, max_value=0.6, step=0.1)
    )(x)
    x = Dense(5, activation='softmax')(x)
    model = tf.keras.Model(inputs=i, outputs=x)

    model.compile(
        loss='categorical_crossentropy',
        metrics=['accuracy'],
        optimizer=Adam(
            learning_rate=hp.Choice('learning_rate', values=[0.003, 0.001, 0.0007, 0.0003, 0.0001])
        )
    )
    return model

# %%
tuner = kt.Hyperband(create_traffic_model,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='/content/drive/My Drive/ML PERSONAL/',
                     project_name='traffic_classifier_model')

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

tuner.search(
    train_generator,
    steps_per_epoch=(train_generator.samples // batch_size)// 3,
    validation_data=validation_generator,
    validation_steps=(validation_generator.samples // batch_size)  // 3,
    batch_size=batch_size,
    callbacks=[stop_early]
)
# Out:
# Trial 32 Complete [00h 04m 11s]
# val_loss: 1.009745717048645
#
# Best val_loss So Far: 0.49334022402763367
# Total elapsed time: 00h 46m 10s
#
# Search: Running Trial #33
#
# Value             |Best Value So Far |Hyperparameter
# avg               |max               |base_model_pooling
# 336               |320               |units_1
# 400               |48                |units_2
# 0.2               |0.2               |dropout_rate_1
# 0.001             |0.001             |learning_rate
# 2                 |4                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 2                 |1                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-e98002832ee1> in <cell line: 14>()
#      12
#      13
# ---> 14 tuner.search(
#      15     train_generator,
#      16     steps_per_epoch=(train_generator.samples // batch_size)// 3, #  using only the first half of the train dataset
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     232
#     233             self.on_trial_begin(trial)
# --> 234             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235             self.on_trial_end(trial)
#     236         self.on_search_end()
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273         try:
# --> 274             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275             trial.status = trial_module.TrialStatus.COMPLETED
#     276             return
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237
#     238     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241             self.oracle.objective.name
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/tuners/hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     425             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427         return super().run_trial(trial, *fit_args, **fit_kwargs)
#     428
#     429     def _build_hypermodel(self, hp):
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     312             callbacks.append(model_checkpoint)
#     313             copied_kwargs["callbacks"] = callbacks
# --> 314             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     315
#     316             histories.append(obj_value)
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     231         hp = trial.hyperparameters
#     232         model = self._try_build(hp)
# --> 233         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     234
#     235         # Save the build config for model loading later.
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     147             If return a float, it should be the `objective` value.
#     148         """
# --> 149         return model.fit(*args, **kwargs)
#     150
#     151
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318                 for step, iterator in epoch_iterator.enumerate_epoch():
#     319                     callbacks.on_train_batch_begin(step)
# --> 320                     logs = self.train_function(iterator)
#     321                     logs = self._pythonify_logs(logs)
#     322                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917           )
#     918       )
# --> 919       return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920           filtered_flat_args,
#     921           self._concrete_variable_creation_fn.captured_inputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
model = tuner.hypermodel.build(best_hps)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ true_divide_1 (TrueDivide)           │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ subtract_1 (Subtract)                │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ xception (Functional)                │ (None, 2048)                │      20,861,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 320)                 │         655,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 320)                 │           1,280 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 48)                  │          15,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 48)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │             245 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,542,285 (82.18 MB)
#  Trainable params: 676,069 (2.58 MB)
#  Non-trainable params: 20,866,216 (79.60 MB)

# %%
# Define the checkpoint callback
checkpoint_cb = ModelCheckpoint(
    filepath='/content/drive/My Drive/ML PERSONAL/last_checkpoint.keras',  # Filepath format

    save_best_only=False,  # Save the model after every epoch
    save_weights_only=False,  # Save the entire model (architecture + weights)
    monitor='val_loss',  # Metric to monitor
    mode='min',  # Save when 'val_loss' decreases
    verbose=1
)

# %%
# Load the saved model
model = load_model('/content/drive/My Drive/ML PERSONAL/last_checkpoint.keras')

# %%
# Train the model and pass the checkpoint callback
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,  # Steps per epoch
    epochs=51,
    initial_epoch=5,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,  # Validation steps
    batch_size=batch_size,
    callbacks=[checkpoint_cb]  # Include the ModelCheckpoint callback
)
# Out:
# Epoch 6/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9370 - loss: 0.1735
# Epoch 6: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 268s 5s/step - accuracy: 0.9370 - loss: 0.1735 - val_accuracy: 0.9196 - val_loss: 0.2044
# Epoch 7/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 0.9102 - loss: 0.2254
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 7: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9102 - loss: 0.2254 - val_accuracy: 0.9074 - val_loss: 0.2590
# Epoch 8/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9355 - loss: 0.1835
# Epoch 8: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 261s 5s/step - accuracy: 0.9355 - loss: 0.1836 - val_accuracy: 0.9113 - val_loss: 0.2466
# Epoch 9/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 0.9219 - loss: 0.2067
# Epoch 9: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.
51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9573 - loss: 0.1203
# Epoch 32: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 260s 5s/step - accuracy: 0.9573 - loss: 0.1204 - val_accuracy: 0.9436 - val_loss: 0.1550
# Epoch 33/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - accuracy: 0.9414 - loss: 0.1749
# Epoch 33: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9414 - loss: 0.1749 - val_accuracy: 0.9444 - val_loss: 0.1557
# Epoch 34/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9534 - loss: 0.1267
# Epoch 34: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 260s 5s/step - accuracy: 0.9534 - loss: 0.1267 - val_accuracy: 0.9280 - val_loss: 0.1897
# Epoch 35/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 0.9453 - loss: 0.1527
# Epoch 35: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9453 - loss: 0.1527 - val_accuracy: 0.9074 - val_loss: 0.1986
# Epoch 36/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9646 - loss: 0.1131
# Epoch 36: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 263s 5s/step - accuracy: 0.9644 - loss: 0.1133 - val_accuracy: 0.9325 - val_loss: 0.1886
# Epoch 37/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 0.9492 - loss: 0.1690
# Epoch 37: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9492 - loss: 0.1690 - val_accuracy: 0.9630 - val_loss: 0.1340
# Epoch 38/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9496 - loss: 0.1449
# Epoch 38: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 265s 5s/step - accuracy: 0.9495 - loss: 0.1450 - val_accuracy: 0.9408 - val_loss: 0.1784
# Epoch 39/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - accuracy: 0.9375 - loss: 0.1718
# Epoch 39: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9375 - loss: 0.1718 - val_accuracy: 0.8981 - val_loss: 0.2385
# Epoch 40/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9557 - loss: 0.1236
# Epoch 40: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 265s 5s/step - accuracy: 0.9556 - loss: 0.1237 - val_accuracy: 0.9492 - val_loss: 0.1382
# Epoch 41/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 0.9375 - loss: 0.1592
# Epoch 41: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9375 - loss: 0.1592 - val_accuracy: 0.9167 - val_loss: 0.1684
# Epoch 42/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9527 - loss: 0.1352
# Epoch 42: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 263s 5s/step - accuracy: 0.9527 - loss: 0.1352 - val_accuracy: 0.9397 - val_loss: 0.1589
# Epoch 43/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - accuracy: 0.9336 - loss: 0.1421
# Epoch 43: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9336 - loss: 0.1421 - val_accuracy: 0.9167 - val_loss: 0.1486
# Epoch 44/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9467 - loss: 0.1512
# Epoch 44: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 264s 5s/step - accuracy: 0.9468 - loss: 0.1509 - val_accuracy: 0.9576 - val_loss: 0.1283
# Epoch 45/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - accuracy: 0.9609 - loss: 0.1105
# Epoch 45: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9609 - loss: 0.1105 - val_accuracy: 0.9722 - val_loss: 0.1300
# Epoch 46/51
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9577 - loss: 0.1123
# Epoch 46: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 263s 5s/step - accuracy: 0.9579 - loss: 0.1121 - val_accuracy: 0.9648 - val_loss: 0.1113
# Epoch 47/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 0.9727 - loss: 0.0983
# Epoch 47: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9727 - loss: 0.0983 - val_accuracy: 0.9630 - val_loss: 0.0774
# Epoch 48/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9596 - loss: 0.1187
# Epoch 48: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 263s 5s/step - accuracy: 0.9595 - loss: 0.1188 - val_accuracy: 0.9565 - val_loss: 0.1254
# Epoch 49/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - accuracy: 0.9609 - loss: 0.1020
# Epoch 49: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9609 - loss: 0.1020 - val_accuracy: 0.9352 - val_loss: 0.1715
# Epoch 50/51
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9634 - loss: 0.1146
# Epoch 50: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 262s 5s/step - accuracy: 0.9634 - loss: 0.1146 - val_accuracy: 0.9615 - val_loss: 0.1178
# Epoch 51/51
#  1/42 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - accuracy: 0.9453 - loss: 0.1506
# Epoch 51: saving model to /content/drive/My Drive/ML PERSONAL/last_checkpoint.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9453 - loss: 0.1506 - val_accuracy: 0.9630 - val_loss: 0.0866

# %% [markdown]
# **Validation**

# %%
score, acc = model.evaluate(validation_generator)
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 982ms/step - accuracy: 0.9568 - loss: 0.1206
# Test Loss = 0.11640612035989761
# Test Accuracy = 0.9605262875556946
